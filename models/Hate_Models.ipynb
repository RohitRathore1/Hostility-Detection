# %% [markdown]
# <a href="https://colab.research.google.com/github/TeAmP0is0N/Fake-News-Hindi/blob/master/models/Hate_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
import numpy as np
import pickle
import copy
import re
import matplotlib.pyplot as plt
from sklearn.externals import joblib

from sklearn import preprocessing
from sklearn.svm import SVC
from sklearn.metrics import f1_score, precision_score, recall_score,accuracy_score
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
pd.options.display.max_colwidth = 0

# %%
#Loading Embedding Features DataFrame

path_temp = r"/gdrive/My Drive/3rd Sem/MTech CSE 3/Thesis/IIITD Fake News Project/Data Set/Embeddings Datasets/Multi-Lingual-BERT/mbert_train.pkl"
f = open(path_temp,'rb')
mbert_train = pickle.load(f)
f.close()

path_temp = r"/gdrive/My Drive/3rd Sem/MTech CSE 3/Thesis/IIITD Fake News Project/Data Set/Embeddings Datasets/Multi-Lingual-BERT/mbert_test.pkl"
f = open(path_temp,'rb')
mbert_test = pickle.load(f)
f.close()

# %%
mbert_train = mbert_train.rename(columns={'Defmatation':'Defamation'})
mbert_test = mbert_test.rename(columns={'Defmatation':'Defamation'})

# %%
mbert_test = copy.deepcopy(mbert_train.iloc[5728:])
mbert_test
# Out:
#              0         1         2  ...  Hate  Offensive  Non-Hostile
# 5728  0.146154  0.547867  0.063385  ...  0     0          1
# 5729 -0.020865  0.457289  0.046067  ...  0     0          0
# 5730  0.230976  0.036649 -0.075142  ...  0     0          1
# 5731 -0.067285  0.318646  0.287195  ...  0     0          1
# 5732 -0.005713  0.370628  0.074260  ...  0     0          1
# ...        ...       ...       ...  ... ..    ..         ..
# 6534 -0.129120 -0.224926 -0.326797  ...  1     0          0
# 6535 -0.803342 -0.510165 -0.088270  ...  0     0          0
# 6536 -0.384648  0.163331 -0.109487  ...  0     0          1
# 6537 -0.412312  0.694740 -0.056614  ...  0     0          1
# 6538  0.220987  0.187707  0.093416  ...  0     0          0
#
# [811 rows x 774 columns]

# %%
mbert_train = mbert_train[:5728]
mbert_train
# Out:
#              0         1         2  ...  Hate  Offensive  Non-Hostile
# 0     0.075584  0.480334  0.207465  ...  1     1          0
# 1    -0.118905  0.228053 -0.107176  ...  0     0          1
# 2    -0.352412  0.891742  0.370846  ...  0     0          1
# 3    -0.202523  0.112649 -0.079444  ...  0     1          0
# 4    -0.186740  0.340729  0.133961  ...  0     0          1
# ...        ...       ...       ...  ... ..    ..         ..
# 5723 -0.300792  0.332828  0.402221  ...  1     0          0
# 5724 -0.067414  0.311470  0.236280  ...  0     0          1
# 5725 -0.265752  0.066230  0.555256  ...  0     0          1
# 5726 -0.062742  0.611168  0.381472  ...  0     0          0
# 5727  0.133602  0.854108  0.274500  ...  0     0          1
#
# [5728 rows x 774 columns]

# %%
mbert_train = mbert_train[mbert_train.Hostile != 0]
mbert_test  = mbert_test[mbert_test.Hostile != 0]

# %%
mbert_train
# Out:
#              0         1         2  ...  Hate  Offensive  Non-Hostile
# 0     0.075584  0.480334  0.207465  ...  1     1          0
# 3    -0.202523  0.112649 -0.079444  ...  0     1          0
# 5    -0.499581  0.077111  0.518150  ...  0     0          0
# 10   -0.206654 -0.154767 -0.077805  ...  1     0          0
# 11    0.018682 -0.073562  0.238370  ...  0     1          0
# ...        ...       ...       ...  ... ..    ..         ..
# 5716  0.312345 -1.197151  0.721082  ...  1     0          0
# 5718 -1.046216 -0.773032  0.509168  ...  0     0          0
# 5722 -0.005968  0.498256 -0.251382  ...  1     1          0
# 5723 -0.300792  0.332828  0.402221  ...  1     0          0
# 5726 -0.062742  0.611168  0.381472  ...  0     0          0
#
# [2678 rows x 774 columns]

# %%
mbert_test
# Out:
#              0         1         2  ...  Hate  Offensive  Non-Hostile
# 5729 -0.020865  0.457289  0.046067  ...  0     0          0
# 5735 -0.004363  0.816025  0.505399  ...  0     0          0
# 5740  0.197693  0.508914  0.101199  ...  0     1          0
# 5741  0.013190  0.362132  0.252457  ...  0     0          0
# 5743 -0.498224 -0.431304  0.428351  ...  1     1          0
# ...        ...       ...       ...  ... ..    ..         ..
# 6527  0.442134  0.045630  0.071684  ...  0     1          0
# 6530 -0.170506 -0.705499  0.529040  ...  0     0          0
# 6534 -0.129120 -0.224926 -0.326797  ...  1     0          0
# 6535 -0.803342 -0.510165 -0.088270  ...  0     0          0
# 6538  0.220987  0.187707  0.093416  ...  0     0          0
#
# [376 rows x 774 columns]

# %%
print(sum(mbert_train['Hostile']))
print(sum(mbert_test['Hostile']))

print(sum(mbert_train['Hate']))
print(sum(mbert_test['Hate']))
# Out:
# 2678
# 376
# 792
# 110

# %%
mbert_train = np.asarray(mbert_train)
mbert_test  = np.asarray(mbert_test)

# %% [markdown]
# #Fine Grained Models

# %%
## -5 for Defamation
## -4 For Fake
## -3 For Hate
## -2 For Offensive

# %% [markdown]
# ##hate Models

# %%
hate_x_train = mbert_train[:,:-6]
hate_y_train = mbert_train[:,-3]

hate_x_test = mbert_test[:,:-6]
hate_y_test = mbert_test[:,-3]

print("hate_x_train: ",hate_x_train.shape)
print("hate_y_train",hate_y_train.shape)
print("hate_x_test",hate_x_test.shape)
print("hate_y_test",hate_y_test.shape)
# Out:
# hate_x_train:  (2678, 768)
# hate_y_train (2678,)
# hate_x_test (376, 768)
# hate_y_test (376,)

# %% [markdown]
# ## SVM for hate Prediction

# %%
print(np.sum(hate_y_train))
print(np.sum(hate_y_test))
# Out:
# 792.0
# 110.0

# %%
# param_grid = {'C': [0.01, 0.1, 1, 10],
#               'gamma': [1,0.1],
#               'kernel': ['rbf','linear']}


# grid = GridSearchCV(SVC(),param_grid,verbose=10)
# grid.fit(x_train,y_train)
# print(grid.best_params_)

# %%
hate_clf = SVC(kernel='linear',C=0.01,gamma=1,class_weight='balanced',verbose=True) ### Earlier C=1, gamma=0.01 gave 76% accuracy
hate_clf.fit(hate_x_train,hate_y_train)
# Out:
# [LibSVM]
# SVC(C=0.01, break_ties=False, cache_size=200, class_weight='balanced',
#     coef0=0.0, decision_function_shape='ovr', degree=3, gamma=1,
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=True)

# %%
#Dumping the SVM Model
# joblib.dump(hate_clf,r"/gdrive/My Drive/3rd Sem/MTech CSE 3/Thesis/IIITD Fake News Project/Notebooks/Models/Fine Grained Models/svm_hate_clf.pkl")
hate_clf = joblib.load(r"/gdrive/My Drive/3rd Sem/MTech CSE 3/Thesis/IIITD Fake News Project/Notebooks/Models/Fine Grained Models/svm_hate_clf.pkl")

# %%
print("\n\nAccuracy report: ")
predict_test = hate_clf.predict(hate_x_test)
print(classification_report(hate_y_test,predict_test))
print(np.unique(predict_test,return_counts = True))
f1 = f1_score(y_true=hate_y_test, y_pred=predict_test, average=None)
print(f1)
# Out:
# Accuracy report:
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.56      0.65       266
#          1.0       0.38      0.65      0.47       110
#
#     accuracy                           0.58       376
#    macro avg       0.58      0.60      0.56       376
# weighted avg       0.67      0.58      0.60       376
#
# (array([0., 1.]), array([187, 189]))
# [0.65342163 0.47491639]

# %%
cm = metrics.confusion_matrix(hate_y_test, predict_test)
plt.figure(figsize=(6,6))
xticklabels = ['Non-hate', 'hate']
yticklabels = ['Non-hate', 'hate']
sns.heatmap(cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'Blues',xticklabels=xticklabels, yticklabels=yticklabels)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 62.15999999999998, 'Predicted label')

# %%
from sklearn.metrics import f1_score
y_true = [0, 1, 2, 0, 1, 2]
y_pred = [0, 2, 1, 0, 0, 1]


a = f1_score(y_true, y_pred, average='weighted')
print(a)

print(classification_report(y_true,y_pred))
# Out:
# 0.26666666666666666
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       0.00      0.00      0.00         2
#            2       0.00      0.00      0.00         2
#
#     accuracy                           0.33         6
#    macro avg       0.22      0.33      0.27         6
# weighted avg       0.22      0.33      0.27         6

# %% [markdown]
# ##Random Forest Classifier

# %%
#Applying Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier
hate_clf = RandomForestClassifier(n_estimators=400).fit(hate_x_train, hate_y_train)

# %%
#Dumping the SVM Model
# joblib.dump(hate_clf,r"/gdrive/My Drive/3rd Sem/MTech CSE 3/Thesis/IIITD Fake News Project/Notebooks/Models/Fine Grained Models/rf_hate_clf.pkl")
hate_clf = joblib.load(r"/gdrive/My Drive/3rd Sem/MTech CSE 3/Thesis/IIITD Fake News Project/Notebooks/Models/Fine Grained Models/rf_hate_clf.pkl")

# %%
print("\n\nAccuracy report: ")
predict_test = hate_clf.predict(hate_x_test)
print(classification_report(hate_y_test,predict_test))
print(np.unique(predict_test,return_counts = True))
f1 = f1_score(y_true=hate_y_test, y_pred=predict_test, average=None)
print(f1)
# Out:
# Accuracy report:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.99      0.83       266
#          1.0       0.57      0.04      0.07       110
#
#     accuracy                           0.71       376
#    macro avg       0.64      0.51      0.45       376
# weighted avg       0.67      0.71      0.61       376
#
# (array([0., 1.]), array([369,   7]))
# [0.82834646 0.06837607]

# %%
cm = metrics.confusion_matrix(hate_y_test, predict_test)
plt.figure(figsize=(6,6))
xticklabels = ['Non-hate', 'hate']
yticklabels = ['Non-hate', 'hate']
sns.heatmap(cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'Blues',xticklabels=xticklabels, yticklabels=yticklabels)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 62.15999999999998, 'Predicted label')

# %% [markdown]
# ##Neural Networks

# %%
from sklearn.neural_network import MLPClassifier

### 768 --> 30 --> 10 --> 2

hate_clf= MLPClassifier(hidden_layer_sizes = (30,10),activation='relu',max_iter=10000,learning_rate_init=0.001)
hate_clf.fit(hate_x_train,hate_y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(30, 10), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=10000,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
# learning_rates = [0.001, 0.005, 0.05, 0.1, 0.5, 1, 2, 5, 10]

# for lr in learning_rates:
#     hate_clf= MLPClassifier(hidden_layer_sizes = (30,10),activation='relu',max_iter=10000)
#     hate_clf.fit(hate_x_train,hate_y_train)
    
#     print("Training set score: %f" % hate_clf.score(hate_x_train, hate_y_train))
#     print("Test set score: %f" % hate_clf.score(hate_x_test, hate_y_test))

# %%
#Dumping the SVM Model
# joblib.dump(hate_clf,r"/gdrive/My Drive/3rd Sem/MTech CSE 3/Thesis/IIITD Fake News Project/Notebooks/Models/Fine Grained Models/mlp_hate_clf.pkl")
hate_clf = joblib.load(r"/gdrive/My Drive/3rd Sem/MTech CSE 3/Thesis/IIITD Fake News Project/Notebooks/Models/Fine Grained Models/mlp_hate_clf.pkl")

# %%
print("\n\nAccuracy report: ")
predict_test = hate_clf.predict(hate_x_test)
print(classification_report(hate_y_test,predict_test))
print(np.unique(predict_test,return_counts = True))
f1 = f1_score(y_true=hate_y_test, y_pred=predict_test, average=None)
print(f1)
# Out:
# Accuracy report:
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.79      0.76       266
#          1.0       0.38      0.32      0.35       110
#
#     accuracy                           0.65       376
#    macro avg       0.56      0.55      0.56       376
# weighted avg       0.63      0.65      0.64       376
#
# (array([0., 1.]), array([285,  91]))
# [0.76225045 0.34825871]

# %%
cm = metrics.confusion_matrix(hate_y_test, predict_test)
plt.figure(figsize=(6,6))
xticklabels = ['Non-hate', 'hate']
yticklabels = ['Non-hate', 'hate']
sns.heatmap(cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'Blues',xticklabels=xticklabels, yticklabels=yticklabels)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 62.15999999999998, 'Predicted label')

# %% [markdown]
# ##Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
hate_clf = 0
hate_clf = LogisticRegression(penalty='l1',solver='liblinear',max_iter=1000,class_weight='balanced').fit(hate_x_train, hate_y_train)

# %%
#Dumping the SVM Model
# joblib.dump(hate_clf,r"/gdrive/My Drive/3rd Sem/MTech CSE 3/Thesis/IIITD Fake News Project/Notebooks/Models/Fine Grained Models/lr_hate_clf.pkl")
hate_clf = joblib.load(r"/gdrive/My Drive/3rd Sem/MTech CSE 3/Thesis/IIITD Fake News Project/Notebooks/Models/Fine Grained Models/lr_hate_clf.pkl")

# %%
print("\n\nAccuracy report: ")
predict_test = hate_clf.predict(hate_x_test)
print(classification_report(hate_y_test,predict_test))
print(np.unique(predict_test,return_counts = True))
f1 = f1_score(y_true=hate_y_test, y_pred=predict_test, average=None)
print(f1)
# Out:
# Accuracy report:
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.65      0.70       266
#          1.0       0.38      0.53      0.44       110
#
#     accuracy                           0.61       376
#    macro avg       0.57      0.59      0.57       376
# weighted avg       0.65      0.61      0.63       376
#
# (array([0., 1.]), array([224, 152]))
# [0.70204082 0.44274809]

# %%
cm = metrics.confusion_matrix(hate_y_test, predict_test)
plt.figure(figsize=(6,6))
xticklabels = ['Non-hate', 'hate']
yticklabels = ['Non-hate', 'hate']
sns.heatmap(cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'Blues',xticklabels=xticklabels, yticklabels=yticklabels)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 62.15999999999998, 'Predicted label')
